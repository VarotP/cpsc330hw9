# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 9: Communication
#
# **Due date: See the [Calendar](https://htmlpreview.github.io/?https://github.com/UBC-CS/cpsc330/blob/master/docs/calendar.html)**

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:2}
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W1/blob/main/docs/homework_instructions.md).
#
# **You may work in a group on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from “1” will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Survival analysis
# <hr>
#
# rubric={points:6}
#
# The following questions pertain to Lecture 21 on survival analysis. We'll consider the use case of customer churn analysis.
#
# 1. What is the problem with simply labeling customers are "churned" or "not churned" and using standard supervised learning techniques?
# 2. Consider customer A who just joined last week vs. customer B who has been with the service for a year. Who do you expect will leave the service first: probably customer A, probably customer B, or we don't have enough information to answer? Briefly explain your answer.
# 3. If a customer's survival function is almost flat during a certain period, how do we interpret that?

# %% [markdown]
# 1. Treating the problem as a binary classification problem is problematic as the trained model would be predicting whether or not a customer will churn at any point in time, which is not as useful a prediction as when the customer will churn.
# 2. Probably customer B, as we can see from survival analysis and also intuitively, the longer a customer stays with a subscription service and does not receive any additional benefits, the more likely they are to churn, therefore a customer who has been with a service for a year longer will be more likely to churn.
# 3. I would interpret that as the customer's satisfaction with the service as constant and is not getting any happier or unsatisfied with the service, and if the survival value is on the higher side means the customer is unlikely to churn for that period.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: Communication
# <hr>

# %% [markdown]
# ### 2.1 Blog post
# rubric={points:26}
#
# Write up your analysis from hw5 or any other assignment or your side project on machine learning in a "blog post" or report format. It's fine if you just write it here in this notebook. Alternatively, you can publish your blog post publicly and include a link here. (See exercise 2.3.) The target audience for your blog post is someone like yourself right before you took this course. They don't necessarily have ML knowledge, but they have a solid foundation in technical matters. The post should focus on explaining **your results and what you did** in a way that's understandable to such a person, **not** a lesson trying to teach someone about machine learning. Again: focus on the results and why they are interesting; avoid pedagogical content.
#
# Your post must include the following elements (not necessarily in this order):
#
# - Description of the problem/decision.
# - Description of the dataset (the raw data and/or some EDA).
# - Description of the model.
# - Description your results, both quantitatively and qualitatively. Make sure to refer to the original problem/decision.
# - A section on caveats, describing at least 3 reasons why your results might be incorrect, misleading, overconfident, or otherwise problematic. Make reference to your specific dataset, model, approach, etc. To check that your reasons are specific enough, make sure they would not make sense, if left unchanged, to most students' submissions; for example, do not just say "overfitting" without explaining why you might be worried about overfitting in your specific case.
# - At least 3 visualizations. These visualizations must be embedded/interwoven into the text, not pasted at the end. The text must refer directly to each visualization. For example "as shown below" or "the figure demonstrates" or "take a look at Figure 1", etc. It is **not** sufficient to put a visualization in without referring to it directly.
#
# A reasonable length for your entire post would be **800 words**. The maximum allowed is **1000 words**.

# %% [markdown]
# #### Example blog posts
#
# Here are some examples of applied ML blog posts that you may find useful as inspiration. The target audiences of these posts aren't necessarily the same as yours, and these posts are longer than yours, but they are well-structured and engaging. You are **not required to read these** posts as part of this assignment - they are here only as examples if you'd find that useful.
#
# From the UBC Master of Data Science blog, written by a past student:
#
# - https://ubc-mds.github.io/2019-07-26-predicting-customer-probabilities/
#
# This next one uses R instead of Python, but that might be good in a way, as you can see what it's like for a reader that doesn't understand the code itself (the target audience for your post here):
#
# - https://rpubs.com/RosieB/taylorswiftlyricanalysis
#
# Finally, here are a couple interviews with winners from Kaggle competitions. The format isn't quite the same as a blog post, but you might find them interesting/relevant:
#
# - https://medium.com/kaggle-blog/instacart-market-basket-analysis-feda2700cded
# - https://medium.com/kaggle-blog/winner-interview-with-shivam-bansal-data-science-for-good-challenge-city-of-los-angeles-3294c0ed1fb2

# %% [markdown]
# #### A note on plagiarism
#
# You may **NOT** include text or visualizations that were not written/created by you. If you are in any doubt as to what constitutes plagiarism, please just ask. For more information see the [UBC Academic Misconduct policies](http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,54,111,959). Please don't copy this from somewhere or ask Generative AI to write it for you 🙏.

# %% [markdown]
# # ML Foundations: A quick guide to machine learning
# by Varot Pavaritpong <br>
# 30th November 2024 <p>
#
# ## Intro
# Have you ever seen those AI videos where they teach an AI how to walk in a video game, or even more sophisticated ones playing games like Tetris, Minesweeper, Flappybird, Super Mario, or even Trackmania? Well today I'm going to be building nothing like that! *(Sort of)* <br>
# ### Problem?
# The problem I had to tackle in this assignment was to predict the popularity of each Airbnb listing based on some information about it. The actual thing we were trying to predict was reviews_per_month, which we interpreted as a way of measuring popularity.
# So lets get started, the first question should always be "What information do we have in the dataset?" This step is called exploratory data analysis and this is what I came up with. <p>
# Firstly, since we had to download the data from kaggle, there is already some information about the dataset on kaggle that describes what each features mean, such as availability_365 being a integer value for how many days of the year the listing is available for, etc. <p>
# Then I used the describe method to look at some information about the distribution of the features (shown below)<p>

# %%
from IPython.display import Image
Image("img/describe.png")

# %% [markdown]
# Here we notice a souple of things, such as some extreme outliers with 10,000$ price and 1250 minimum_nights!? We also get information about the mean and the standard variation of each feature, which gives us a better understanding of the data. <br>
# Then I visualized the listings by the given longitude and latitude (shown below) <p>

# %%
Image("img/visual.png")

# %% [markdown]
# This is exactly what I had hoped for with the visualization, that it would be an outline of New York. We can see the shape of long island on the right and staten island on the bottom. Manhattan is a little hard to spot with so many points crammed in the middle, but overall it gives us a rough idea of the distribution of listings in New York visually.
# Then I confirmed some assumptions about the data given my observations  (shown below) <p>

# %%
Image("img/assumptions.png")

# %% [markdown]
# I had a little done goof when I received the homework back and saw that I didn't create two visualizations like they had asked for, so that's why its a little lacking in images here. <br>
# Given the problem to predict the popularity of the listing, measured by reviews_per_month, which is a continuous value, I decided that the model we should use would be a regression model, which outputs a continuous value as opposed to a classification model which outputs discrete classes. I also decide to choose R^2, which is a measure of the prediction score to the mean of the real target. There are also other metrics I could've chosen such as MAPE, or RMSE, however they take more time to calculate as the default output of the model's scores are already in R^2, which is why I chose it.

# %% [markdown]
# ## Feature Engineering and Preprocessing

# %% [markdown]
# We're not yet done with the data though, and this step in the machine learning process is arguably one of the most important steps that can massively impact the model. <br>
# Feature engineering is the process of coming up with additional features from our dataset that could be useful for the model. The two features I came up with for this problem was "days_since_last_review" - taking the concrete dates and subtracting it with the date of the data collection, and "price_per_night" - dividing the price with the minimum nights per stay. <p>
# Then it's time for preprocessing, the process of getting the data into the right form for our model. I do a couple things to the data, such as imputing missing values and scaling for numeric columns, and creating new columns for each class in each row that is a categorical feature (OneHotEncoding). (Example code shown below)

# %%
Image("img/preprocessing.png")

# %% [markdown]
# ## Model training and Results

# %% [markdown]
# Now it's finally time for the fun part! We always train a dummy model first as a baseline case to compare our other models to, in my case the DummyRegressor had a R^2 score of 0, which means it is working perfectly as intended. The DummyRegressor is made to always predict the mean, and with some math the R^2 score will come out to 0 as it does not deviate from the mean.

# %%
Image("img/dummy.png")

# %% [markdown]
# I then try a bunch of different models, ranging from simple linear models such a Ridge, to more complex models such as RandomForestRegressor or KNeighborsRegressor. I also do hyperparameter tuning on Ridge as requested, which is a process of trying to optimize the parameters we give to the model that increases/decreases it's complexity in order to achieve better results. In my case, Ridge has a hyperparameter called 'alpha' that increases it's complexity. The Ridge results are shown below

# %%
Image("img/ridge.png")

# %% [markdown]
# Here we can see that the mean train scores and mean cv scores are pretty low all across the board, however the mean cv score seems to peak at alpha = 10. Now for the results of the more complex models

# %%
Image("img/complex.png")

# %% [markdown]
# Sorry for the formatting, but we can see that KNeighboursRegressor has a mean cv score of 0.474, LightGBM with 0.676 and RandomForestRegressor with 0.663. With these results, I decided that the best model that I would use going forward would be LightGBM, not only because it had one of the better mean cv scores, but also that it is 50 times faster to train than RandomForestRegressor, which makes experimenting and completing the assignment a lot quicker. LightGBM is a gradient boosted ensemble model which uses a bunch of weaker models combined together into one, which makes it fast to train. I would also like to mention the fact that RanfomForestRegressor had a mean train score of 0.95, compare to LightGBM's 0.76, which means that the RFR is likely overfit.
# ## Feature Selection
# Next up is feature selection, taking out unimportant features to try to improve results. I used an algorithm that recursively removes the least important feature and trains the model to see the score, and the results are below

# %%
Image("img/feature.png")

# %% [markdown]
# Above we see that firstly we have a lot of features, due to the onehotencoding, but also that the cv score does not increase in the slightest as we remove features (read from right to left). As a result, I decided to skip this step for my model altogether. <p>
# Lastly I did some hyperparameter optimization for LightGBM using RandomizedGridSearch and the results are below.

# %%
Image("img/gridsearch.png")

# %%
Image("img/results.png")

# %% [markdown]
# ## Final Results
# Above we can see the final results of all the models into one table. There are some missing scores because I did not bother to train all of them, however I did test all of them on the test set. Fortunately the results come out as expected, and the optimized LightGBM wins in final test R^2 score, with a final score of 0.623. This is by all means not the greatest score for a model, it is like saying "Our model can explain 62% of the variance in predicting an Airbnb listing's popularity", however it is not a bad effort and way better than the baseline model, which predicts it 0%.

# %% [markdown]
# ### Caveats
# There are always some caveats when applying machine learning to real world problems. <br>
# The first caveat is in the problem statement itself, we are using reviews_per_month as a proxy for popularity, which is not necessarily true in the real world. For example when a new restaurant opens there are a lot of inital reviews due to the hype surrounding the opening, and there could be some cases similar to this for Airbnb listings as well. <br>
# Second caveat is that during the feature engineering step, I used the latest date found in the dataset as the date of data collection, which I could not confirm on Kaggle or elsewhere that it is the actual date of data collection, and in the feature importances step I discovered that it was the most important feature in terms of predicting the popularity. <br>
# Lastly due to the data collection method, the dataset fails to capture the temporal aspect of popularity, as Airbnb listings and hotels get more customers during high seasons and some even close during low season, and the final prediction is a prediction of the popularity of the listing at the date of data collection, which is in 2019.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2.2 Effective communication technique
# rubric={points:4}
#
# Describe one effective communication technique that you used in your post, or an aspect of the post that you are particularly satisfied with. (Max 3 sentences.)

# %% [markdown]
# I liked the use of images and sections for example code and data visualization as I myself am more of a visual learner, so being able to see actual code and results in image form is better for learning in my opinion.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### (optional, not for marks) 2.3
#
# Publish your blog post from 1.1 publicly using a tool like [Quarto](https://quarto.org/), or somewhere like medium.com, and paste a link here. Be sure to pick a tool in which code and code output look reasonable. This link could be a useful line on your resume!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Your takeaway from the course
# rubric={points:2}
#
# **Your tasks:**
#
# - Reflect on your journey through this course. Please identify and elaborate on at least three key concepts or experiences where you had an "aha" moment. How would you use the concepts learned in this course in your personal projects or how would you approach your past projects differently based on the insights gained in this course? We encourage you to dig deep and share your genuine reflections.
#
# > Please write thoughtful answers. We are looking forward to reading them 🙂.

# %% [markdown]
# This is my first "data sciency" type of course and had plenty of "aha" moments. From looking at different ways to preprocess data for better results, or better yet feature engineering which is something I would've never thought of myself. Looking and visualizing feature importances was also great as we just spent so much preprocessing the data, it got me thinking if it was even worth the time, and it makes the model more interpretable. The key takeaway from this course for me is the framing of the problem itself, as we have many targets we could optimize a ML model for, as well as many metrics to choose from to evaluate it, which can be applied to other areas of life such as businesses or even personal goals. I know that many businesses these days are more data oriented rather than based on heuristic and seeing ML in a business context definitely grounds the material compared to delving into theory like in 340 (full disclosure haven't taken it).

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# ### Congratulations 👏👏
#
# That's all for the assignments! Congratulations on finishing all homework assignments!

# %%
# !echo $PATH
# Out:
# /usr/local/opt/cocoapods/bin:/opt/miniconda3/envs/cpsc330/bin:/opt/miniconda3/condabin:/Users/evlav/.rbenv/shims:/usr/local/bin:/usr/local/sbin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/Library/Apple/usr/bin:/Applications/Wireshark.app/Contents/MacOS:/usr/local/go/bin

# %%
from IPython.display import Image

Image("img/eva-congrats.png")
